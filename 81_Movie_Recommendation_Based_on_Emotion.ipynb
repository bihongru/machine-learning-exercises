# %% [markdown]
# ### Step 1: Import Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import requests
from bs4 import BeautifulSoup
import re

# %% [markdown]
# ### Step 2: Constant

# %%
URLS = {
    "Drama": 'https://www.imdb.com/search/title/?title_type=feature&genres=drama',
    "Action": 'https://www.imdb.com/search/title/?title_type=feature&genres=action',
    "Comedy": 'https://www.imdb.com/search/title/?title_type=feature&genres=comedy',
    "Horror": 'https://www.imdb.com/search/title/?title_type=feature&genres=horror',
    "Crime": 'https://www.imdb.com/search/title/?title_type=feature&genres=crime',
}

# %%
HEADERS = {
    'User-Agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %% [markdown]
# ### Step 3: Web Scraping

# %%
def MovieRecommendation(emotion, num):
    url = URLS.get('Drama')
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
    soup = BeautifulSoup(response.text, "lxml")
    titles = list(map(lambda x: x.text, soup.select('a.ipc-title-link-wrapper')))
    return titles[:num]

# %%
titles = MovieRecommendation('Drama', 5)

# %%
for title in titles:
    print(title)
# Out:
# 1. Project Hail Mary
# 2. Sinners
# 3. Hamnet
# 4. The Bride!
# 5. One Battle After Another
